# %% [markdown]
# ## **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Connecting to Kegel**

# %%
# !find /content/drive -name "kaggle.json"
# Out:
# /content/drive/MyDrive/Colab Notebooks/kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/Colab Notebooks/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # **Download dataset**

# %%
# !kaggle datasets download -d rohingarg12/faceforensics-1000
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rohingarg12/faceforensics-1000
# License(s): other
# ...
# 100% 484M/484M [00:05<00:00, 96.1MB/s]

# %%
#Extract the dataset from the zip file and save it to the desired location
# !unzip -q faceforensics-1000.zip -d data

# %%
# !du -sh data
# Out:
# 501M	data
